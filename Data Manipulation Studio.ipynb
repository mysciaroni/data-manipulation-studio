# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

atlanta_df = pd.read_csv("dataset/atlanta_9-24-2016_9-30-2017.csv")
baltimore_df = pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
boston_df = pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
chicago_df = pd.read_csv("dataset/chicago_9-24-2016_9-30-2017.csv")
columbia_df = pd.read_csv("dataset/columbia_9-24-2016_9-30-2017.csv")
dallas_df = pd.read_csv("dataset/dallas_9-24-2016_9-30-2017.csv")
detroit_df = pd.read_csv("dataset/detroit_9-24-2016_9-30-2017.csv")
la_df = pd.read_csv("dataset/los-angeles_9-24-2016_9-30-2017.csv")
miami_df = pd.read_csv("dataset/miami_9-24-2016_9-30-2017.csv")
new_york_df = pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
philly_df = pd.read_csv("dataset/philadelphia_9-24-2016_9-30-2017.csv")
sf_df = pd.read_csv("dataset/san-fransisco_9-24-2016_9-30-2017.csv")
stl_df = pd.read_csv("dataset/st-louis_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
#baltimore data cleaning below

# %%
baltimore_df.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
baltimore_df.shape
# Out:
# (153, 25)

# %%
duplicate_rows_baltimore_df = baltimore_df[baltimore_df.duplicated()]
print("Number of duplicated rows: ", duplicate_rows_baltimore_df.shape)
# Out:
# Number of duplicated rows:  (0, 25)

# %%
for col in baltimore_df.columns:
    pct_missing = np.mean(baltimore_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
#boston data cleaning below

# %%
boston_df.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...   Color  Environment  \
# 0    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 1    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 2    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 3    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 4    NaN  09/24/2016        160         180  ...  ORANGE          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
boston_df.shape
# Out:
# (352, 25)

# %%
duplicate_rows_boston_df = boston_df[boston_df.duplicated()]
print("Number of duplicated rows: ", duplicate_rows_boston_df.shape)
# Out:
# Number of duplicated rows:  (0, 25)

# %%
for col in boston_df.columns:
    pct_missing = np.mean(boston_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
#new york data cleaning

# %%
new_york_df.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
new_york_df.shape
# Out:
# (112, 25)

# %%
duplicate_rows_new_york_df = new_york_df[new_york_df.duplicated()]
print("Number of duplicated rows: ", duplicate_rows_new_york_df.shape)
# Out:
# Number of duplicated rows:  (0, 25)

# %%
for col in new_york_df.columns:
    pct_missing = np.mean(new_york_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
#philidelphia data cleaning below

# %%
philly_df.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN  NaN       N
# 1          NaN      NaN       NaN         NaN      NaN  NaN       N
# 2          NaN      NaN       NaN         NaN      NaN  NaN       N
# 3          NaN      NaN       NaN         NaN      NaN  NaN       N
# 4          NaN      NaN       NaN         NaN      NaN  NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 25 columns]

# %%
philly_df.shape
# Out:
# (57, 25)

# %%
duplicate_rows_philly_df = philly_df[philly_df.duplicated()]
print("Number of duplicated rows: ", duplicate_rows_philly_df.shape)
# Out:
# Number of duplicated rows:  (0, 25)

# %%
for col in philly_df.columns:
    pct_missing = np.mean(philly_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# Clean your data here!
northeast = pd.concat([baltimore_df, boston_df, new_york_df, philly_df], ignore_index=True)

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
northeast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Commodity Name   674 non-null    object
#  1   City Name        674 non-null    object
#  2   Type             0 non-null      float64
#  3   Package          674 non-null    object
#  4   Variety          672 non-null    object
#  5   Sub Variety      83 non-null     object
#  6   Grade            0 non-null      float64
#  7   Date             674 non-null    object
#  8   Low Price        674 non-null    int64
#  9   High Price       674 non-null    float64
#  10  Mostly Low       674 non-null    int64
#  11  Mostly High      674 non-null    float64
#  12  Origin           669 non-null    object
#  13  Origin District  81 non-null     object
#  14  Item Size        625 non-null    object
#  15  Color            356 non-null    object
#  16  Environment      0 non-null      float64
#  17  Unit of Sale     106 non-null    object
#  18  Quality          0 non-null      float64
#  19  Condition        0 non-null      float64
#  20  Appearance       0 non-null      float64
#  21  Storage          0 non-null      float64
#  22  Crop             0 non-null      float64
#  23  Repack           674 non-null    object
#  24  Trans Mode       0 non-null      float64
# dtypes: float64(11), int64(2), object(12)
# memory usage: 131.8+ KB

# %%
northeast = northeast.dropna(axis=1, how="all")

# %%
northeast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Commodity Name   674 non-null    object
#  1   City Name        674 non-null    object
#  2   Package          674 non-null    object
#  3   Variety          672 non-null    object
#  4   Sub Variety      83 non-null     object
#  5   Date             674 non-null    object
#  6   Low Price        674 non-null    int64
#  7   High Price       674 non-null    float64
#  8   Mostly Low       674 non-null    int64
#  9   Mostly High      674 non-null    float64
#  10  Origin           669 non-null    object
#  11  Origin District  81 non-null     object
#  12  Item Size        625 non-null    object
#  13  Color            356 non-null    object
#  14  Unit of Sale     106 non-null    object
#  15  Repack           674 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 84.4+ KB

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
northeast['Unit of Sale'].dropna().value_counts()
# Out:
# PER BIN       71
# EACH          24
# SHELLACKED    11
# Name: Unit of Sale, dtype: int64

# %%
northeast[(northeast["Unit of Sale"] == 'PER BIN')].describe()
# Out:
#         Low Price  High Price  Mostly Low  Mostly High
# count   71.000000   71.000000   71.000000    71.000000
# mean   185.845070  206.619718  193.521127   204.859155
# std     44.529171   48.342341   47.767251    48.967714
# min    120.000000  140.000000  120.000000   140.000000
# 25%    160.000000  180.000000  160.000000   175.000000
# 50%    175.000000  200.000000  185.000000   200.000000
# 75%    200.000000  225.000000  210.000000   225.000000
# max    300.000000  300.000000  300.000000   300.000000

# %%
# northeast.groupby(['Unit of Sale']).mean()
northeast.groupby("Unit of Sale").agg({'Low Price':'mean', 'High Price':'mean'})
# Out:
#                Low Price  High Price
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
# northeast.columns
ne_gk = northeast.groupby(['Variety', 'City Name'])
ne_gk.agg("mean")
# Out:
#                                         Low Price  High Price  Mostly Low  \
# Variety                  City Name
# BIG MACK TYPE            BALTIMORE      47.916667   59.166667   47.916667
#                          BOSTON        200.689655  224.827586  215.689655
#                          NEW YORK       75.000000   80.000000   75.000000
# BLUE TYPE                BOSTON        260.000000  285.000000  285.000000
# CINDERELLA               BALTIMORE     175.840000  185.120000  175.840000
#                          BOSTON        260.000000  285.000000  285.000000
# FAIRYTALE                BALTIMORE     225.625000  238.750000  225.625000
#                          BOSTON        178.333333  195.333333  195.000000
# HOWDEN TYPE              BALTIMORE     137.600000  149.200000  137.600000
#                          BOSTON        163.257576  195.984848  172.348485
#                          NEW YORK      143.717949  159.102564  143.846154
#                          PHILADELPHIA  130.000000  138.035714  130.714286
# HOWDEN WHITE TYPE        BALTIMORE     170.000000  180.000000  170.000000
# KNUCKLE HEAD             BOSTON        260.000000  285.000000  285.000000
#                          NEW YORK      120.000000  140.000000  120.000000
#                          PHILADELPHIA  210.000000  210.000000  210.000000
# MINIATURE                BALTIMORE      16.066667   16.666667   16.066667
#                          BOSTON         15.000000   18.000000   15.000000
#                          NEW YORK       18.296296   19.259259   18.518519
#                          PHILADELPHIA   16.166667   17.583333   16.166667
# MIXED HEIRLOOM VARIETIES BALTIMORE     213.333333  240.000000  213.333333
#                          NEW YORK      200.000000  200.000000  200.000000
# PIE TYPE                 BALTIMORE      35.769231   36.442308   35.769231
#                          BOSTON        162.324561  183.605263  169.280702
#                          NEW YORK      129.261905  138.595238  129.500000
#                          PHILADELPHIA   96.875000  101.750000   96.875000
#
#                                        Mostly High
# Variety                  City Name
# BIG MACK TYPE            BALTIMORE       59.166667
#                          BOSTON         221.379310
#                          NEW YORK        80.000000
# BLUE TYPE                BOSTON         285.000000
# CINDERELLA               BALTIMORE      185.120000
#                          BOSTON         285.000000
# FAIRYTALE                BALTIMORE      238.125000
#                          BOSTON         195.000000
# HOWDEN TYPE              BALTIMORE      148.400000
#                          BOSTON         176.098485
#                          NEW YORK       159.102564
#                          PHILADELPHIA   138.035714
# HOWDEN WHITE TYPE        BALTIMORE      180.000000
# KNUCKLE HEAD             BOSTON         285.000000
#                          NEW YORK       140.000000
#                          PHILADELPHIA   210.000000
# MINIATURE                BALTIMORE       16.666667
#                          BOSTON          15.000000
#                          NEW YORK        19.185185
#                          PHILADELPHIA    17.583333
# MIXED HEIRLOOM VARIETIES BALTIMORE      240.000000
#                          NEW YORK       200.000000
# PIE TYPE                 BALTIMORE       36.442308
#                          BOSTON         174.017544
#                          NEW YORK       138.452381
#                          PHILADELPHIA   101.750000

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
